# %%
import sqlalchemy
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func
from sqlalchemy import Column, Float, Integer, String, Date
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
import sqlite3

# %matplotlib inline

# %%
filepath = "/IMDB_Movies_2021.db"

# %%
engine = create_engine(f"sqlite:///Resources/IMDB_Movies_2021.db")

# %%
df = pd.read_sql("SELECT AUTHOR, TITLE, REVIEW, RATING FROM REVIEWS", engine)
df.head(50)
# Out:
#                   AUTHOR                                              TITLE  \
# 0        margarida-44311                                          Not Bad\n
# 1               joemay-2   What are all the bad reviews about is it a wo...
# 2                   nebk                            Great White=Jaws Lite\n
# 3              kuarinofu                     Bare-bones killer shark film\n
# 4   Horror_Flick_Fanatic                Terrible story, dialogue, and CGI\n
# 5          NickyDee07938                                  A decent effort\n
# 6              Novelwolf                                Nice Shark movie!\n
# 7                   mbnn                Nice, but could be so much better\n
# 8               phobicsq                      Typical movie for the genre\n
# 9           rotini-52586                                       Liked it !\n
# 10             ops-52535                                its raft fever...\n
# 11  seventhriotontheship                                          Jaws 57\n
# 12     hossamahmed-30148                                    Below average\n
# 13            divealanya                                 Total junk movie\n
# 14         twinmom-10035                                    Waste of time\n
# 15        paul_haakonsen     A very exciting and thrilling shark movie...\n
# 16            gsyfrafjrp                         Waste of time and money!\n
# 17        ryanlion-38514                            All Dialogue No Shark\n
# 18                kaefab   far fetch and the usual stranded with shark m...
# 19                katiha                                      Oh Dear God\n
# 20        benjamin-ensor                          Why bother making this?\n
# 21           PennywiseFA   Good popcorn fun, don't expect any realism he...
# 22           JoelChamp85                                     What A Waste\n
# 23    agnethagillbanks20                    What's with the low rating!!!\n
# 24        imcaufieldholt                         Even the shark was bored\n
# 25      lukemurray-40846                              Standard shark film\n
# 26             pjkaustin                         Great white load of crap\n
# 27                 JICNZ             Worth A Watch For Comedic Value Only\n
# 28              jkingliz                Good concept, bad representation.\n
# 29             amesmonde    A mixed bucket of chum with a great last act.\n
# 30        nogodnomasters                                 What about "it"?\n
# 31             Lythas_85                                         terrible\n
# 32              irlmchan                                   Crap just crap\n
# 33              omendata   Not bad for a low budget shark movie - Shark ...
# 34               ant36au                  Doesn't deserve the bad reviews\n
# 35         hockeyguy9119                                             SSDD\n
# 36            neil-60137                             Great White is awful\n
# 37      Draysan-Jennings                                 47 Meters Down??\n
# 38     whitemanfromtowne                    Starts stupid and gets worse.\n
# 39  richardcarlsen-69748                        Jaws if it was a TV movie\n
# 40      bmasterson-96598                            CHEESY BUT I LIKED IT\n
# 41               umnolol                               Watched this drunk\n
# 42      paul-ayres-60784                         Some very tense moments.\n
# 43        greenhouse3505                                     Worth a look\n
# 44           coryh-30073                       Disney Channel shark movie\n
# 45           yvesdemaria                       Loved the first 30 minutes\n
# 46             heliparts   All those that gave this less than a 5 are id...
# 47           vengeance20            A Shark Version Of Black Water: Abyss\n
# 48      vassiliskounelis                                       Emmm why ?\n
# 49             andynicko                                             Jeez\n
#
#                                                REVIEW  RATING
# 0   I don't get all the terrible reviews for this ...     5.0
# 1   I cannot believe anyone could give this film l...     8.0
# 2   Great White is not the worst way to spend 90 m...     4.0
# 3   Great White is as basic of a killer shark film...     4.0
# 4   Terrible story, dialogue and CGI. The film has...     4.0
# 5   Whilst the 'shark survival' sub genre has plen...     6.0
# 6   Much better than the ratings suggest. Its on p...     9.0
# 7   First of all I love the film locations, drone ...     5.0
# 8   The film is meh when it comes to these types o...     4.0
# 9   Thought it was a great Shark Movie . Special e...     7.0
# 10  At least well 2/3's of the movie, its grumpy m...     3.0
# 11  Many have tried to replicate the success of St...     3.0
# 12  When u come to watch a typical shark movie , y...     1.0
# 13  Bad CGI and rubbish story. Really!!!The female...     1.0
# 14  I am very impressed how a mouth to mouth under...     2.0
# 15  Finally a shark movie that is well-worth divin...     7.0
# 16  Totally waste of time and money, worst movie t...     1.0
# 17  I think I looked at the screen like twice for ...     2.0
# 18  Yes the movie is far fetch some effects are pr...     3.0
# 19  Evet a child would write a better dialogues be...     3.0
# 20  The EXACT plot has been done so many times bef...     2.0
# 21  Five people on a rescue mission in shark infes...     6.0
# 22  I love shark films, but I don't know who to bl...     4.0
# 23  Okay so first I am a big fan of shark movies. ...     8.0
# 24  Avoid "Great White"! It is just boring. The ch...     1.0
# 25  Ill bullet point instead of writing a story.Ty...     3.0
# 26  What a load of rubbish, acting was bad, story ...     2.0
# 27  This was so dreadful it's worth watching to la...     NaN
# 28  Honestly the story line and concept was great,...     3.0
# 29  A seaplane operator couple and their passenger...     NaN
# 30  Luke doesn't make it through the opening scene...     3.0
# 31  The plot per se was stupid..\ncome on.. you se...     2.0
# 32  Tourists charter a sea plane to visit a seclud...     1.0
# 33  I also cannot fathom some reviewers either as ...     4.0
# 34  Great White really doesn't deserve the bad rev...     7.0
# 35  The story is bland. The actors are bland. The ...     1.0
# 36  New worst movie I've ever seen! Not only does ...     1.0
# 37  This film is advertised as if it's from the ex...     5.0
# 38  A dumbass aussie pilot decides to play search ...     1.0
# 39  I am the biggest Jaws fan in the world, just l...     6.0
# 40  Not as bad as is being made out by some review...     6.0
# 41  Laughed at the first scene, kept laughing at t...     2.0
# 42  Another shark tale.. But much better than most...     8.0
# 43  It's funny, that over the last twelve months m...     6.0
# 44  The first maybe 10 minutes was decent, after t...     2.0
# 45  Great scenery, camera work, set up of the stor...     6.0
# 46  All those that gave this less than a 5 are idi...    10.0
# 47  Had a feeling this film was going to be bad bu...     1.0
# 48  Weird how stupid the script was.The film was b...     1.0
# 49  Worst shark film ever, and didn't think sharks...     1.0

# %%
df.count()
# Out:
# AUTHOR    5450
# TITLE     5450
# REVIEW    5450
# RATING    5332
# dtype: int64

# %%
clean_df = df.dropna(how='any')

clean_df
# Out:
#                     AUTHOR                                              TITLE  \
# 0          margarida-44311                                          Not Bad\n
# 1                 joemay-2   What are all the bad reviews about is it a wo...
# 2                     nebk                            Great White=Jaws Lite\n
# 3                kuarinofu                     Bare-bones killer shark film\n
# 4     Horror_Flick_Fanatic                Terrible story, dialogue, and CGI\n
# ...                    ...                                                ...
# 5445         suryajijvania                                       More Parts\n
# 5446      shishirkmr-82243                           It's a fantastic movie\n
# 5447        moizsyed-07601                            Awesome out standing!\n
# 5448        samun_shrestha                                             EPIC\n
# 5449       mmuradali-65680                      The best DC movie till date\n
#
#                                                  REVIEW  RATING
# 0     I don't get all the terrible reviews for this ...     5.0
# 1     I cannot believe anyone could give this film l...     8.0
# 2     Great White is not the worst way to spend 90 m...     4.0
# 3     Great White is as basic of a killer shark film...     4.0
# 4     Terrible story, dialogue and CGI. The film has...     4.0
# ...                                                 ...     ...
# 5445  It's master piece by Zack please part 2,3,4 al...    10.0
# 5446  No words to describe. It's awesome. One of the...    10.0
# 5447  Far better than previous one and better editin...    10.0
# 5448  Why did the studio say no to this masterpiece?...    10.0
# 5449  Overall Opinion-\nAlthough the competitors Mar...    10.0
#
# [5332 rows x 4 columns]

# %%
clean_df.replace('\n', '')
# Out:
#                     AUTHOR                                              TITLE  \
# 0          margarida-44311                                            Not Bad
# 1                 joemay-2   What are all the bad reviews about is it a wo...
# 2                     nebk                              Great White=Jaws Lite
# 3                kuarinofu                       Bare-bones killer shark film
# 4     Horror_Flick_Fanatic                  Terrible story, dialogue, and CGI
# ...                    ...                                                ...
# 5445         suryajijvania                                         More Parts
# 5446      shishirkmr-82243                             It's a fantastic movie
# 5447        moizsyed-07601                              Awesome out standing!
# 5448        samun_shrestha                                               EPIC
# 5449       mmuradali-65680                        The best DC movie till date
#
#                                                  REVIEW  RATING
# 0     I don't get all the terrible reviews for this ...     5.0
# 1     I cannot believe anyone could give this film l...     8.0
# 2     Great White is not the worst way to spend 90 m...     4.0
# 3     Great White is as basic of a killer shark film...     4.0
# 4     Terrible story, dialogue and CGI. The film has...     4.0
# ...                                                 ...     ...
# 5445  It's master piece by Zack please part 2,3,4 al...    10.0
# 5446  No words to describe. It's awesome. One of the...    10.0
# 5447  Far better than previous one and better editin...    10.0
# 5448  Why did the studio say no to this masterpiece?...    10.0
# 5449  Overall Opinion-Although the competitors Marve...    10.0
#
# [5332 rows x 4 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-2d98758513c8> in <module>
#       1 IMDB_clean_df = clean_df
#       2
# ----> 3 IMBD_clean_df
#
# NameError: name 'IMBD_clean_df' is not defined
