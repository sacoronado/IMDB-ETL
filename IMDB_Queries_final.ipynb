# %%
import sqlalchemy
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func
from sqlalchemy import Column, Float, Integer, String, Date
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.ext.automap import automap_base

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
import sqlite3 as db

# %matplotlib inline

# %%
#Establish path to the CSV file that was created from the cleaning dataframe
IMDB_data_path = "../Project 2/clean_IMDB_data.csv"

# %%
#Create a new dataframe from the clean CSV
IMDB_data = pd.read_csv(IMDB_data_path)

IMDB_df = pd.DataFrame(IMDB_data)

del IMDB_df['Unnamed: 0']

IMDB_df
# Out:
#                     AUTHOR                                              TITLE  \
# 0          margarida-44311                                            Not Bad
# 1                 joemay-2   What are all the bad reviews about is it a wo...
# 2                     nebk                              Great White=Jaws Lite
# 3                kuarinofu                       Bare-bones killer shark film
# 4     Horror_Flick_Fanatic                  Terrible story, dialogue, and CGI
# ...                    ...                                                ...
# 5327         suryajijvania                                         More Parts
# 5328      shishirkmr-82243                             It's a fantastic movie
# 5329        moizsyed-07601                              Awesome out standing!
# 5330        samun_shrestha                                               EPIC
# 5331       mmuradali-65680                        The best DC movie till date
#
#                                                  REVIEW  RATING
# 0     I don't get all the terrible reviews for this ...     5.0
# 1     I cannot believe anyone could give this film l...     8.0
# 2     Great White is not the worst way to spend 90 m...     4.0
# 3     Great White is as basic of a killer shark film...     4.0
# 4     Terrible story, dialogue and CGI. The film has...     4.0
# ...                                                 ...     ...
# 5327  It's master piece by Zack please part 2,3,4 al...    10.0
# 5328  No words to describe. It's awesome. One of the...    10.0
# 5329  Far better than previous one and better editin...    10.0
# 5330  Why did the studio say no to this masterpiece?...    10.0
# 5331  Overall Opinion-Although the competitors Marve...    10.0
#
# [5332 rows x 4 columns]

# %%
#Create and author dataframe to load to the new sqlite db authors table.
author = pd.DataFrame(IMDB_df['AUTHOR'])

author
# Out:
#                     AUTHOR
# 0          margarida-44311
# 1                 joemay-2
# 2                     nebk
# 3                kuarinofu
# 4     Horror_Flick_Fanatic
# ...                    ...
# 5327         suryajijvania
# 5328      shishirkmr-82243
# 5329        moizsyed-07601
# 5330        samun_shrestha
# 5331       mmuradali-65680
#
# [5332 rows x 1 columns]

# %%
# Create dataframe for the Authors table and rename the index to be the author_id 
# ----------------------------------
author_df = author.drop_duplicates().reset_index(drop=True)
author_df = author_df.rename_axis("author_id")

author_df.rename(columns = {'AUTHOR':'author_name'}, inplace=True)

author_df
# Out:
#                     author_name
# author_id
# 0               margarida-44311
# 1                      joemay-2
# 2                          nebk
# 3                     kuarinofu
# 4          Horror_Flick_Fanatic
# ...                         ...
# 4673              suryajijvania
# 4674           shishirkmr-82243
# 4675             moizsyed-07601
# 4676             samun_shrestha
# 4677            mmuradali-65680
#
# [4678 rows x 1 columns]

# %%
# Create dataframe for the movies table
movie_df = pd.DataFrame(IMDB_df[['TITLE', 'REVIEW', 'RATING', 'AUTHOR']])
movie_df = movie_df.rename_axis("movie_id")
movie_df.rename(columns = {'TITLE': 'movie_title', 'REVIEW':'movie_review', 'RATING':'movie_rating', 'AUTHOR':'author_name'}, inplace=True)

movie_df
# Out:
#                                                 movie_title  \
# movie_id
# 0                                                   Not Bad
# 1          What are all the bad reviews about is it a wo...
# 2                                     Great White=Jaws Lite
# 3                              Bare-bones killer shark film
# 4                         Terrible story, dialogue, and CGI
# ...                                                     ...
# 5327                                             More Parts
# 5328                                 It's a fantastic movie
# 5329                                  Awesome out standing!
# 5330                                                   EPIC
# 5331                            The best DC movie till date
#
#                                                movie_review  movie_rating  \
# movie_id
# 0         I don't get all the terrible reviews for this ...           5.0
# 1         I cannot believe anyone could give this film l...           8.0
# 2         Great White is not the worst way to spend 90 m...           4.0
# 3         Great White is as basic of a killer shark film...           4.0
# 4         Terrible story, dialogue and CGI. The film has...           4.0
# ...                                                     ...           ...
# 5327      It's master piece by Zack please part 2,3,4 al...          10.0
# 5328      No words to describe. It's awesome. One of the...          10.0
# 5329      Far better than previous one and better editin...          10.0
# 5330      Why did the studio say no to this masterpiece?...          10.0
# 5331      Overall Opinion-Although the competitors Marve...          10.0
#
#                    author_name
# movie_id
# 0              margarida-44311
# 1                     joemay-2
# 2                         nebk
# 3                    kuarinofu
# 4         Horror_Flick_Fanatic
# ...                        ...
# 5327             suryajijvania
# 5328          shishirkmr-82243
# 5329            moizsyed-07601
# 5330            samun_shrestha
# 5331           mmuradali-65680
#
# [5332 rows x 4 columns]

# %%
# Create engine for establishing the new sqlite db
# ----------------------------------
engine = create_engine(f"sqlite:///IMDB2.sqlite")
conn = engine.connect()

# %%
#Use engine.execute to create the table schema and set primary key
engine.execute('CREATE TABLE "authors" ('
               'author_id INTEGER NOT NULL PRIMARY KEY,'
               'author_name VARCHAR);')

# %%
#Load the data from the authors dataframe to the sqlite authors table
author_df.to_sql(name='authors', con=conn, if_exists='append', index=True, index_label="author_id")

# %%
# read database and create authors dataframe to merge with the movies dataframe
# ----------------------------------
authors = pd.read_sql('select * from authors', conn)

authors
# Out:
#       author_id           author_name
# 0             0       margarida-44311
# 1             1              joemay-2
# 2             2                  nebk
# 3             3             kuarinofu
# 4             4  Horror_Flick_Fanatic
# ...         ...                   ...
# 4673       4673         suryajijvania
# 4674       4674      shishirkmr-82243
# 4675       4675        moizsyed-07601
# 4676       4676        samun_shrestha
# 4677       4677       mmuradali-65680
#
# [4678 rows x 2 columns]

# %%
#merge dataframes to create movie table to prepare to populate the movie sqlite table and use author_id as the link between the authors 
#and movie tables
combined_table = pd.merge(authors, movie_df, on="author_name")

combined_table
# Out:
#       author_id      author_name  \
# 0             0  margarida-44311
# 1             1         joemay-2
# 2             2             nebk
# 3             3        kuarinofu
# 4             3        kuarinofu
# ...         ...              ...
# 5327       4675   moizsyed-07601
# 5328       4676   samun_shrestha
# 5329       4676   samun_shrestha
# 5330       4677  mmuradali-65680
# 5331       4677  mmuradali-65680
#
#                                             movie_title  \
# 0                                               Not Bad
# 1      What are all the bad reviews about is it a wo...
# 2                                 Great White=Jaws Lite
# 3                          Bare-bones killer shark film
# 4                              Quite a good sci-fi film
# ...                                                 ...
# 5327                              Awesome out standing!
# 5328                                               EPIC
# 5329                                               EPIC
# 5330                        The best DC movie till date
# 5331                        The best DC movie till date
#
#                                            movie_review  movie_rating
# 0     I don't get all the terrible reviews for this ...           5.0
# 1     I cannot believe anyone could give this film l...           8.0
# 2     Great White is not the worst way to spend 90 m...           4.0
# 3     Great White is as basic of a killer shark film...           4.0
# 4     The plot itself is not unique and is rather a ...           7.0
# ...                                                 ...           ...
# 5327  Far better than previous one and better editin...          10.0
# 5328  Why did the studio say no to this masterpiece?...          10.0
# 5329  Why did the studio say no to this masterpiece?...          10.0
# 5330  Overall Opinion-Although the competitors Marve...          10.0
# 5331  Overall Opinion-Although the competitors Marve...          10.0
#
# [5332 rows x 5 columns]

# %%
#Create a new dataframe to drop the author_name and set the index as the movie_id
combined_table2 = pd.DataFrame(combined_table, columns=['author_id', 'movie_title', 'movie_review', 'movie_rating'])
combined_table2 = combined_table2.rename_axis("movie_id")                               
combined_table2
# Out:
#           author_id                                        movie_title  \
# movie_id
# 0                 0                                            Not Bad
# 1                 1   What are all the bad reviews about is it a wo...
# 2                 2                              Great White=Jaws Lite
# 3                 3                       Bare-bones killer shark film
# 4                 3                           Quite a good sci-fi film
# ...             ...                                                ...
# 5327           4675                              Awesome out standing!
# 5328           4676                                               EPIC
# 5329           4676                                               EPIC
# 5330           4677                        The best DC movie till date
# 5331           4677                        The best DC movie till date
#
#                                                movie_review  movie_rating
# movie_id
# 0         I don't get all the terrible reviews for this ...           5.0
# 1         I cannot believe anyone could give this film l...           8.0
# 2         Great White is not the worst way to spend 90 m...           4.0
# 3         Great White is as basic of a killer shark film...           4.0
# 4         The plot itself is not unique and is rather a ...           7.0
# ...                                                     ...           ...
# 5327      Far better than previous one and better editin...          10.0
# 5328      Why did the studio say no to this masterpiece?...          10.0
# 5329      Why did the studio say no to this masterpiece?...          10.0
# 5330      Overall Opinion-Although the competitors Marve...          10.0
# 5331      Overall Opinion-Although the competitors Marve...          10.0
#
# [5332 rows x 4 columns]

# %%
#Use engine.execute to create the table schema and set primary key
engine.execute('CREATE TABLE "movies" ('
               'movie_id INTEGER NOT NULL PRIMARY KEY,'
               'author_id INTEGER NOT NULL,'
               'movie_title VARCHAR,'
               'movie_review VARCHAR,'
            'movie_rating FLOAT);')

# %%
#Load the dataframe data to the sqlite db movies table
combined_table2.to_sql(name='movies', con=conn, if_exists='append', index=True, index_label="movie_id")

# %%
# read database to create a new dataframe that includes the author_id
# ----------------------------------
movies = pd.read_sql('select * from movies', conn)

movies
# Out:
#       movie_id  author_id                                        movie_title  \
# 0            0          0                                            Not Bad
# 1            1          1   What are all the bad reviews about is it a wo...
# 2            2          2                              Great White=Jaws Lite
# 3            3          3                       Bare-bones killer shark film
# 4            4          3                           Quite a good sci-fi film
# ...        ...        ...                                                ...
# 5327      5327       4675                              Awesome out standing!
# 5328      5328       4676                                               EPIC
# 5329      5329       4676                                               EPIC
# 5330      5330       4677                        The best DC movie till date
# 5331      5331       4677                        The best DC movie till date
#
#                                            movie_review  movie_rating
# 0     I don't get all the terrible reviews for this ...           5.0
# 1     I cannot believe anyone could give this film l...           8.0
# 2     Great White is not the worst way to spend 90 m...           4.0
# 3     Great White is as basic of a killer shark film...           4.0
# 4     The plot itself is not unique and is rather a ...           7.0
# ...                                                 ...           ...
# 5327  Far better than previous one and better editin...          10.0
# 5328  Why did the studio say no to this masterpiece?...          10.0
# 5329  Why did the studio say no to this masterpiece?...          10.0
# 5330  Overall Opinion-Although the competitors Marve...          10.0
# 5331  Overall Opinion-Although the competitors Marve...          10.0
#
# [5332 rows x 5 columns]

# %%
#Query to aggregat rating statistics by author based on dataframe from the original database
auth_agg_df2 = IMDB_df.groupby(['AUTHOR'])

count = auth_agg_df2["RATING"].count()
rating_mean = auth_agg_df2["RATING"].mean()
rating_median = auth_agg_df2["RATING"].median()
rating_min = auth_agg_df2["RATING"].min()
rating_max = auth_agg_df2['RATING'].max()

aggregate_df = pd.DataFrame({"Rating Count": count, "Rating Mean": rating_mean, "Rating Median": rating_median, "Rating Min": rating_min,
                             "Rating Max": rating_max})

auth_agg = aggregate_df.sort_values(['Rating Count'], ascending=False)

auth_agg.head(50)
# Out:
#                       Rating Count  Rating Mean  Rating Median  Rating Min  \
# AUTHOR
# Xstal                           10     6.100000            7.0         3.0
# kwenchow                        10     1.500000            1.0         1.0
# yusufpiskin                      9     6.888889            8.0         3.0
# cruise01                         9     5.333333            5.0         2.0
# nogodnomasters                   9     5.777778            5.0         3.0
# ops-52535                        9     5.444444            6.0         2.0
# SnoopyStyle                      8     5.125000            5.0         3.0
# Golden_Hope                      8     5.500000            5.5         4.0
# ThomDerd                         8     6.000000            6.0         3.0
# Top_Dawg_Critic                  8     6.875000            7.0         3.0
# atractiveeyes                    7     6.571429            7.0         3.0
# msbreviews                       7     6.285714            8.0         2.0
# joscon-16616                     7     7.142857            7.0         6.0
# sweidman-28016                   7     6.857143            7.0         2.0
# trinaboice                       7     5.857143            5.0         2.0
# Jo_Blo_Movie_Critic              6     6.000000            6.0         3.0
# whitemanfromtowne                6     2.000000            1.5         1.0
# rnixon-15663                     6     6.333333            6.0         3.0
# ferguson-6                       6     6.166667            6.0         4.0
# Horror_Flick_Fanatic             6     4.333333            4.0         1.0
# JoelChamp85                      5     6.600000            7.0         4.0
# jeroduptown                      5     5.200000            5.0         4.0
# stevendbeard                     5     5.800000            6.0         3.0
# chandean-69762                   5     5.200000            4.0         1.0
# itsbobr                          5     5.600000            7.0         2.0
# Movi3DO                          5     4.400000            3.0         1.0
# RosanaBotafogo                   5     8.200000            8.0         8.0
# ks-60500                         5     3.800000            4.0         2.0
# kuarinofu                        5     4.400000            4.0         1.0
# masonsaul                        5     7.400000            7.0         6.0
# faer_kr                          5     4.200000            5.0         1.0
# masonfisk                        5     7.000000            7.0         6.0
# alindsay-al                      5     4.200000            4.0         3.0
# Cineanalyst                      5     5.200000            4.0         3.0
# paul-allaer                      5     6.000000            6.0         5.0
# joostkale                        5     6.200000            6.0         5.0
# rotini-52586                     5     2.800000            2.0         1.0
# Draysan-Jennings                 5     5.200000            5.0         5.0
# jadepietro                       5     8.000000            8.0         7.0
# tccandler                        4     2.750000            2.0         2.0
# strawberries68-1                 4     4.250000            3.0         2.0
# jp_91                            4     5.250000            5.5         2.0
# carlos-pires                     4     2.000000            2.0         1.0
# LmH82                            4     7.750000           10.0         1.0
# Xavier_Stone                     4     1.750000            2.0         1.0
# kxxxxxx                          4     6.500000            6.5         4.0
# kosmasp                          4     7.000000            7.5         5.0
# rannynm                          4     7.750000            8.0         5.0
# gab-67599                        4     8.000000            9.0         4.0
# Fella_shibby                     4     7.750000            8.0         7.0
#
#                       Rating Max
# AUTHOR
# Xstal                        9.0
# kwenchow                     6.0
# yusufpiskin                  9.0
# cruise01                     8.0
# nogodnomasters              10.0
# ops-52535                   10.0
# SnoopyStyle                  8.0
# Golden_Hope                  7.0
# ThomDerd                     9.0
# Top_Dawg_Critic              9.0
# atractiveeyes                9.0
# msbreviews                  10.0
# joscon-16616                 8.0
# sweidman-28016               9.0
# trinaboice                  10.0
# Jo_Blo_Movie_Critic          9.0
# whitemanfromtowne            4.0
# rnixon-15663                 9.0
# ferguson-6                   8.0
# Horror_Flick_Fanatic         8.0
# JoelChamp85                  8.0
# jeroduptown                  6.0
# stevendbeard                 7.0
# chandean-69762               9.0
# itsbobr                      7.0
# Movi3DO                      8.0
# RosanaBotafogo               9.0
# ks-60500                     5.0
# kuarinofu                    7.0
# masonsaul                    9.0
# faer_kr                      9.0
# masonfisk                    8.0
# alindsay-al                  7.0
# Cineanalyst                  8.0
# paul-allaer                  7.0
# joostkale                    8.0
# rotini-52586                 7.0
# Draysan-Jennings             6.0
# jadepietro                  10.0
# tccandler                    5.0
# strawberries68-1             9.0
# jp_91                        8.0
# carlos-pires                 3.0
# LmH82                       10.0
# Xavier_Stone                 2.0
# kxxxxxx                      9.0
# kosmasp                      8.0
# rannynm                     10.0
# gab-67599                   10.0
# Fella_shibby                 8.0

# %%
#Query to aggregate author rating statistics based on dataframe created from the new sqlite db to include the author ID.
auth_agg_df3 = combined_table.groupby(['author_name', 'author_id'])

count = auth_agg_df3["movie_rating"].count()
rating_mean = auth_agg_df3["movie_rating"].mean()
rating_median = auth_agg_df3["movie_rating"].median()
rating_min = auth_agg_df3["movie_rating"].min()
rating_max = auth_agg_df3['movie_rating'].max()

aggregate_df = pd.DataFrame({"Rating Count": count, "Rating Mean": rating_mean, "Rating Median": rating_median, "Rating Min": rating_min,
                             "Rating Max": rating_max})

auth_agg2 = aggregate_df.sort_values(['Rating Count'], ascending=False)

auth_agg2.head(50)
# Out:
#                                 Rating Count  Rating Mean  Rating Median  \
# author_name          author_id
# Xstal                49                   10     6.100000            7.0
# kwenchow             485                  10     1.500000            1.0
# yusufpiskin          976                   9     6.888889            8.0
# cruise01             824                   9     5.333333            5.0
# nogodnomasters       28                    9     5.777778            5.0
# ops-52535            10                    9     5.444444            6.0
# SnoopyStyle          87                    8     5.125000            5.0
# Golden_Hope          170                   8     5.500000            5.5
# ThomDerd             221                   8     6.000000            6.0
# Top_Dawg_Critic      51                    8     6.875000            7.0
# atractiveeyes        400                   7     6.571429            7.0
# msbreviews           382                   7     6.285714            8.0
# joscon-16616         113                   7     7.142857            7.0
# sweidman-28016       665                   7     6.857143            7.0
# trinaboice           857                   7     5.857143            5.0
# Jo_Blo_Movie_Critic  779                   6     6.000000            6.0
# whitemanfromtowne    36                    6     2.000000            1.5
# rnixon-15663         1009                  6     6.333333            6.0
# ferguson-6           415                   6     6.166667            6.0
# Horror_Flick_Fanatic 4                     6     4.333333            4.0
# JoelChamp85          22                    5     6.600000            7.0
# jeroduptown          81                    5     5.200000            5.0
# stevendbeard         647                   5     5.800000            6.0
# chandean-69762       1024                  5     5.200000            4.0
# itsbobr              104                   5     5.600000            7.0
# Movi3DO              510                   5     4.400000            3.0
# RosanaBotafogo       1171                  5     8.200000            8.0
# ks-60500             405                   5     3.800000            4.0
# kuarinofu            3                     5     4.400000            4.0
# masonsaul            171                   5     7.400000            7.0
# faer_kr              509                   5     4.200000            5.0
# masonfisk            1180                  5     7.000000            7.0
# alindsay-al          1139                  5     4.200000            4.0
# Cineanalyst          943                   5     5.200000            4.0
# paul-allaer          934                   5     6.000000            6.0
# joostkale            1213                  5     6.200000            6.0
# rotini-52586         9                     5     2.800000            2.0
# Draysan-Jennings     35                    5     5.200000            5.0
# jadepietro           778                   5     8.000000            8.0
# tccandler            115                   4     2.750000            2.0
# strawberries68-1     2428                  4     4.250000            3.0
# jp_91                631                   4     5.250000            5.5
# carlos-pires         1566                  4     2.000000            2.0
# LmH82                235                   4     7.750000           10.0
# Xavier_Stone         992                   4     1.750000            2.0
# kxxxxxx              179                   4     6.500000            6.5
# kosmasp              1434                  4     7.000000            7.5
# rannynm              559                   4     7.750000            8.0
# gab-67599            86                    4     8.000000            9.0
# Fella_shibby         742                   4     7.750000            8.0
#
#                                 Rating Min  Rating Max
# author_name          author_id
# Xstal                49                3.0         9.0
# kwenchow             485               1.0         6.0
# yusufpiskin          976               3.0         9.0
# cruise01             824               2.0         8.0
# nogodnomasters       28                3.0        10.0
# ops-52535            10                2.0        10.0
# SnoopyStyle          87                3.0         8.0
# Golden_Hope          170               4.0         7.0
# ThomDerd             221               3.0         9.0
# Top_Dawg_Critic      51                3.0         9.0
# atractiveeyes        400               3.0         9.0
# msbreviews           382               2.0        10.0
# joscon-16616         113               6.0         8.0
# sweidman-28016       665               2.0         9.0
# trinaboice           857               2.0        10.0
# Jo_Blo_Movie_Critic  779               3.0         9.0
# whitemanfromtowne    36                1.0         4.0
# rnixon-15663         1009              3.0         9.0
# ferguson-6           415               4.0         8.0
# Horror_Flick_Fanatic 4                 1.0         8.0
# JoelChamp85          22                4.0         8.0
# jeroduptown          81                4.0         6.0
# stevendbeard         647               3.0         7.0
# chandean-69762       1024              1.0         9.0
# itsbobr              104               2.0         7.0
# Movi3DO              510               1.0         8.0
# RosanaBotafogo       1171              8.0         9.0
# ks-60500             405               2.0         5.0
# kuarinofu            3                 1.0         7.0
# masonsaul            171               6.0         9.0
# faer_kr              509               1.0         9.0
# masonfisk            1180              6.0         8.0
# alindsay-al          1139              3.0         7.0
# Cineanalyst          943               3.0         8.0
# paul-allaer          934               5.0         7.0
# joostkale            1213              5.0         8.0
# rotini-52586         9                 1.0         7.0
# Draysan-Jennings     35                5.0         6.0
# jadepietro           778               7.0        10.0
# tccandler            115               2.0         5.0
# strawberries68-1     2428              2.0         9.0
# jp_91                631               2.0         8.0
# carlos-pires         1566              1.0         3.0
# LmH82                235               1.0        10.0
# Xavier_Stone         992               1.0         2.0
# kxxxxxx              179               4.0         9.0
# kosmasp              1434              5.0         8.0
# rannynm              559               5.0        10.0
# gab-67599            86                4.0        10.0
# Fella_shibby         742               7.0         8.0

# %%
auth_agg3 = auth_agg2[(auth_agg2['Rating Count'] >=5) & (auth_agg2['Rating Mean'] >=7)]

auth_agg3 = auth_agg3.sort_values(['Rating Mean'], ascending=False)

auth_agg3
# Out:
#                           Rating Count  Rating Mean  Rating Median  \
# author_name    author_id
# RosanaBotafogo 1171                  5     8.200000            8.0
# jadepietro     778                   5     8.000000            8.0
# masonsaul      171                   5     7.400000            7.0
# joscon-16616   113                   7     7.142857            7.0
# masonfisk      1180                  5     7.000000            7.0
#
#                           Rating Min  Rating Max
# author_name    author_id
# RosanaBotafogo 1171              8.0         9.0
# jadepietro     778               7.0        10.0
# masonsaul      171               6.0         9.0
# joscon-16616   113               6.0         8.0
# masonfisk      1180              6.0         8.0
